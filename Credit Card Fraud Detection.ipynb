# %% [markdown]
# # OPEN-ENDED EXPERIEMENT

# %% [markdown]
# # EXPERIMENT 12

# %% [markdown]
# ###### Step 1: Problem Statement
# Build a Credit Card Fraud Detection system using XGBoost Classifier.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ###### Step 2: Data Collection

# %%
df = pd.read_csv(r'./dataset/creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#    Amount  Class
# 0  149.62    0.0
# 1    2.69    0.0
# 2  378.66    0.0
# 3  123.50    0.0
# 4   69.99    0.0

# %% [markdown]
# ###### Step 3: Exploratory Data Analysis

# %%
df.shape
# Out:
# (174418, 31)

# %%
df = df.iloc[::10]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17442 entries, 0 to 174410
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    17442 non-null  float64
#  1   V1      17442 non-null  float64
#  2   V2      17442 non-null  float64
#  3   V3      17442 non-null  float64
#  4   V4      17442 non-null  float64
#  5   V5      17442 non-null  float64
#  6   V6      17442 non-null  float64
#  7   V7      17442 non-null  float64
#  8   V8      17442 non-null  float64
#  9   V9      17442 non-null  float64
#  10  V10     17442 non-null  float64
#  11  V11     17442 non-null  float64
#  12  V12     17442 non-null  float64
#  13  V13     17442 non-null  float64
#  14  V14     17442 non-null  float64
#  15  V15     17442 non-null  float64
#  16  V16     17442 non-null  float64
#  17  V17     17442 non-null  float64
#  18  V18     17442 non-null  float64
#  19  V19     17442 non-null  float64
#  20  V20     17442 non-null  float64
#  21  V21     17442 non-null  float64
#  22  V22     17442 non-null  float64
#  23  V23     17442 non-null  float64
#  24  V24     17442 non-null  float64
#  25  V25     17442 non-null  float64
#  26  V26     17442 non-null  float64
#  27  V27     17442 non-null  float64
#  28  V28     17442 non-null  float64
#  29  Amount  17442 non-null  float64
#  30  Class   17442 non-null  float64
# dtypes: float64(31)
# memory usage: 4.1 MB

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count   17442.000000  17442.000000  17442.000000  17442.000000  17442.000000
# mean    62306.668788     -0.182510      0.060768      0.464435      0.116918
# std     28817.650256      1.912230      1.595214      1.463478      1.379954
# min         0.000000    -34.591213    -44.639245    -31.103685     -4.837170
# 25%     41573.250000     -0.994979     -0.532830     -0.090369     -0.741453
# 50%     61580.000000     -0.201811      0.118246      0.610579      0.106134
# 75%     79435.750000      1.190251      0.817360      1.292211      0.930187
# max    121901.000000      2.399241     16.713389      3.934998     11.906170
#
#                  V5            V6            V7            V8            V9  \
# count  17442.000000  17442.000000  17442.000000  17442.000000  17442.000000
# mean      -0.182373      0.045699     -0.086859      0.033401      0.018771
# std        1.402493      1.305151      1.270450      1.265268      1.151930
# min      -23.611865    -23.496714    -26.548144    -27.156906     -8.739670
# 25%       -0.804904     -0.695281     -0.589515     -0.165057     -0.660606
# 50%       -0.224995     -0.208737     -0.022861      0.052372     -0.073942
# 75%        0.372580      0.431783      0.468313      0.348606      0.639405
# max       34.099309     16.493227     21.437514     20.007208     10.348407
#
#                 V10           V11           V12           V13           V14  \
# count  17442.000000  17442.000000  17442.000000  17442.000000  17442.000000
# mean      -0.021788      0.182329     -0.094470      0.063390      0.076247
# std        1.110433      1.058837      1.150428      1.050231      1.000713
# min      -18.271168     -4.682931    -17.182918     -3.785719    -16.337596
# 25%       -0.516297     -0.576319     -0.512477     -0.631231     -0.350104
# 50%       -0.103698      0.110874      0.113181      0.031907      0.093011
# 75%        0.409485      0.982302      0.617068      0.740931      0.527304
# max       15.331742     10.063790      4.318071      3.904562      7.176161
#
#                 V15           V16           V17           V18           V19  \
# count  17442.000000  17442.000000  17442.000000  17442.000000  17442.000000
# mean       0.125865      0.000085      0.039897     -0.060755     -0.009006
# std        0.945533      0.885573      0.931436      0.834524      0.810833
# min       -3.879892    -12.375397    -21.090613     -8.061208     -4.619034
# 25%       -0.463910     -0.456940     -0.417848     -0.536516     -0.483628
# 50%        0.230832      0.062468     -0.015718     -0.058235     -0.010115
# 75%        0.818229      0.533223      0.435658      0.423738      0.477474
# max        4.803689      4.816252      9.253526      4.295648      4.555359
#
#                 V20           V21           V22           V23           V24  \
# count  17442.000000  17442.000000  17442.000000  17442.000000  17442.000000
# mean       0.024859     -0.027377     -0.077635     -0.017460      0.008022
# std        0.688310      0.757314      0.670811      0.569652      0.599577
# min      -13.440832    -14.031579     -5.573222    -20.794422     -2.732373
# 25%       -0.184432     -0.231630     -0.547218     -0.167869     -0.333878
# 50%       -0.035650     -0.054258     -0.059868     -0.033779      0.058928
# 75%        0.155581      0.130053      0.372975      0.103997      0.411572
# max       16.178535     19.290955      4.799794     17.297845      3.998294
#
#                 V25           V26           V27           V28        Amount  \
# count  17442.000000  17442.000000  17442.000000  17442.000000  17442.000000
# mean       0.086796      0.009871      0.006943     -0.000758     84.783117
# std        0.467920      0.486962      0.390244      0.301501    226.896421
# min       -4.781606     -1.603645     -8.567638     -8.257218      0.000000
# 25%       -0.205925     -0.329897     -0.063477     -0.029640      5.200000
# 50%        0.129264     -0.054939      0.009750      0.020627     20.295000
# 75%        0.395945      0.260401      0.094903      0.078495     76.000000
# max        2.401621      3.463246      8.254376     15.866721   7879.420000
#
#               Class
# count  17442.000000
# mean       0.002179
# std        0.046626
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class     float64
# dtype: object

# %%
# Correlation matrix
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
# Checking for NaN values in the dataset
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Visualizing the outliers
fig=plt.figure(figsize=(15,5))
plt.boxplot(df, labels=df.columns)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c82aafcf10>,
#   <matplotlib.lines.Line2D at 0x1c82ab254f0>,
#   <matplotlib.lines.Line2D at 0x1c82abe8b80>,
#   <matplotlib.lines.Line2D at 0x1c82ac13190>,
#   <matplotlib.lines.Line2D at 0x1c82acd8640>,
#   <matplotlib.lines.Line2D at 0x1c82a5d51c0>,
#   <matplotlib.lines.Line2D at 0x1c82a5f18e0>,
#   <matplotlib.lines.Line2D at 0x1c82a5fb1f0>,
#   <matplotlib.lines.Line2D at 0x1c829ca9b50>,
#   <matplotlib.lines.Line2D at 0x1c829ca9ee0>,
#   <matplotlib.lines.Line2D at 0x1c82ace4ee0>,
#   <matplotlib.lines.Line2D at 0x1c82a60f940>,
#   <matplotlib.lines.Line2D at 0x1c82a5c8fa0>,
#   <matplotlib.lines.Line2D at 0x1c82a5c84f0>,
#   <matplotlib.lines.Line2D at 0x1c82ad00be0>,
#   <matplotlib.lines.Line2D at 0x1c82ad00f70>,
#   <matplotlib.lines.Line2D at 0x1c82ad0ddc0>,
#   <matplotlib.lines.Line2D at 0x1c82ad0d7c0>,
#   <matplotlib.lines.Line2D at 0x1c82adcb100>,
#   <matplotlib.lines.Line2D at 0x1c82adcb460>,
#   <matplotlib.lines.Line2D at 0x1c82addc8e0>,
#   <matplotlib.lines.Line2D at 0x1c82addcc40>,
#   <matplotlib.lines.Line2D at 0x1c82adee100>,
#   <matplotlib.lines.Line2D at 0x1c82adee460>,
#   <matplotlib.lines.Line2D at 0x1c82adfd8e0>,
#   <matplotlib.lines.Line2D at 0x1c82adfdc40>,
#   <matplotlib.lines.Line2D at 0x1c829dd4100>,
#   <matplotlib.lines.Line2D at 0x1c829dd4460>,
#   <matplotlib.lines.Line2D at 0x1c829dde8e0>,
#   <matplotlib.lines.Line2D at 0x1c829ddec40>,
#   <matplotlib.lines.Line2D at 0x1c829df7100>,
#   <matplotlib.lines.Line2D at 0x1c829df7460>,
#   <matplotlib.lines.Line2D at 0x1c829e008e0>,
#   <matplotlib.lines.Line2D at 0x1c829e00c40>,
#   <matplotlib.lines.Line2D at 0x1c829e1a100>,
#   <matplotlib.lines.Line2D at 0x1c829e1a460>,
#   <matplotlib.lines.Line2D at 0x1c829e268e0>,
#   <matplotlib.lines.Line2D at 0x1c829e26c40>,
#   <matplotlib.lines.Line2D at 0x1c829e3e100>,
#   <matplotlib.lines.Line2D at 0x1c829e3e460>,
#   <matplotlib.lines.Line2D at 0x1c829e4a8e0>,
#   <matplotlib.lines.Line2D at 0x1c829e4ac40>,
#   <matplotlib.lines.Line2D at 0x1c829e61100>,
#   <matplotlib.lines.Line2D at 0x1c829e61460>,
#   <matplotlib.lines.Line2D at 0x1c829e6c8e0>,
#   <matplotlib.lines.Line2D at 0x1c829e6cc40>,
#   <matplotlib.lines.Line2D at 0x1c829e84100>,
#   <matplotlib.lines.Line2D at 0x1c829e84460>,
#   <matplotlib.lines.Line2D at 0x1c829e8e8e0>,
#   <matplotlib.lines.Line2D at 0x1c829e8ec40>,
#   <matplotlib.lines.Line2D at 0x1c829ea6100>,
#   <matplotlib.lines.Line2D at 0x1c829ea6460>,
#   <matplotlib.lines.Line2D at 0x1c829eb18e0>,
#   <matplotlib.lines.Line2D at 0x1c829eb1c40>,
#   <matplotlib.lines.Line2D at 0x1c829ec9100>,
#   <matplotlib.lines.Line2D at 0x1c829ec9460>,
#   <matplotlib.lines.Line2D at 0x1c829ed38e0>,
#   <matplotlib.lines.Line2D at 0x1c829ed3c40>,
#   <matplotlib.lines.Line2D at 0x1c829eeb100>,
#   <matplotlib.lines.Line2D at 0x1c829eeb460>,
#   <matplotlib.lines.Line2D at 0x1c829ef78e0>,
#   <matplotlib.lines.Line2D at 0x1c829ef7c40>],
#  'caps': [<matplotlib.lines.Line2D at 0x1c82ab41a90>,
#   <matplotlib.lines.Line2D at 0x1c82ab6a0a0>,
#   <matplotlib.lines.Line2D at 0x1c82ac2f790>,
#   <matplotlib.lines.Line2D at 0x1c82ac4bd30>,
#   <matplotlib.lines.Line2D at 0x1c82a5d59d0>,
#   <matplotlib.lines.Line2D at 0x1c82a5d5400>,
#   <matplotlib.lines.Line2D at 0x1c82a5fb3d0>,
#   <matplotlib.lines.Line2D at 0x1c82a5fbfa0>,
#   <matplotlib.lines.Line2D at 0x1c82acff730>,
#   <matplotlib.lines.Line2D at 0x1c82acff280>,
#   <matplotlib.lines.Line2D at 0x1c82a60f5b0>,
#   <matplotlib.lines.Line2D at 0x1c829ca4d00>,
#   <matplotlib.lines.Line2D at 0x1c82a60aa90>,
#   <matplotlib.lines.Line2D at 0x1c82a60a640>,
#   <matplotlib.lines.Line2D at 0x1c82ad092b0>,
#   <matplotlib.lines.Line2D at 0x1c82ad09fd0>,
#   <matplotlib.lines.Line2D at 0x1c82ad0d160>,
#   <matplotlib.lines.Line2D at 0x1c82adc0340>,
#   <matplotlib.lines.Line2D at 0x1c82adcb7c0>,
#   <matplotlib.lines.Line2D at 0x1c82adcbb20>,
#   <matplotlib.lines.Line2D at 0x1c82addcfa0>,
#   <matplotlib.lines.Line2D at 0x1c82ade7340>,
#   <matplotlib.lines.Line2D at 0x1c82adee7c0>,
#   <matplotlib.lines.Line2D at 0x1c82adeeb20>,
#   <matplotlib.lines.Line2D at 0x1c82adfdfa0>,
#   <matplotlib.lines.Line2D at 0x1c829dc9340>,
#   <matplotlib.lines.Line2D at 0x1c829dd47c0>,
#   <matplotlib.lines.Line2D at 0x1c829dd4b20>,
#   <matplotlib.lines.Line2D at 0x1c829ddefa0>,
#   <matplotlib.lines.Line2D at 0x1c829dea340>,
#   <matplotlib.lines.Line2D at 0x1c829df77c0>,
#   <matplotlib.lines.Line2D at 0x1c829df7b20>,
#   <matplotlib.lines.Line2D at 0x1c829e00fa0>,
#   <matplotlib.lines.Line2D at 0x1c829e0e340>,
#   <matplotlib.lines.Line2D at 0x1c829e1a7c0>,
#   <matplotlib.lines.Line2D at 0x1c829e1ab20>,
#   <matplotlib.lines.Line2D at 0x1c829e26fa0>,
#   <matplotlib.lines.Line2D at 0x1c829e32340>,
#   <matplotlib.lines.Line2D at 0x1c829e3e7c0>,
#   <matplotlib.lines.Line2D at 0x1c829e3eb20>,
#   <matplotlib.lines.Line2D at 0x1c829e4afa0>,
#   <matplotlib.lines.Line2D at 0x1c829e56340>,
#   <matplotlib.lines.Line2D at 0x1c829e617c0>,
#   <matplotlib.lines.Line2D at 0x1c829e61b20>,
#   <matplotlib.lines.Line2D at 0x1c829e6cfa0>,
#   <matplotlib.lines.Line2D at 0x1c829e77340>,
#   <matplotlib.lines.Line2D at 0x1c829e847c0>,
#   <matplotlib.lines.Line2D at 0x1c829e84b20>,
#   <matplotlib.lines.Line2D at 0x1c829e8efa0>,
#   <matplotlib.lines.Line2D at 0x1c829e9b340>,
#   <matplotlib.lines.Line2D at 0x1c829ea67c0>,
#   <matplotlib.lines.Line2D at 0x1c829ea6b20>,
#   <matplotlib.lines.Line2D at 0x1c829eb1fa0>,
#   <matplotlib.lines.Line2D at 0x1c829ebc340>,
#   <matplotlib.lines.Line2D at 0x1c829ec97c0>,
#   <matplotlib.lines.Line2D at 0x1c829ec9b20>,
#   <matplotlib.lines.Line2D at 0x1c829ed3fa0>,
#   <matplotlib.lines.Line2D at 0x1c829ede340>,
#   <matplotlib.lines.Line2D at 0x1c829eeb7c0>,
#   <matplotlib.lines.Line2D at 0x1c829eebb20>,
#   <matplotlib.lines.Line2D at 0x1c829ef7fa0>,
#   <matplotlib.lines.Line2D at 0x1c829f01340>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1c82aadf970>,
#   <matplotlib.lines.Line2D at 0x1c82abce5e0>,
#   <matplotlib.lines.Line2D at 0x1c82acade50>,
#   <matplotlib.lines.Line2D at 0x1c82a5f1df0>,
#   <matplotlib.lines.Line2D at 0x1c82a5de7f0>,
#   <matplotlib.lines.Line2D at 0x1c82a5e5490>,
#   <matplotlib.lines.Line2D at 0x1c82a5c8cd0>,
#   <matplotlib.lines.Line2D at 0x1c82ad008b0>,
#   <matplotlib.lines.Line2D at 0x1c82ad0da60>,
#   <matplotlib.lines.Line2D at 0x1c82adc0d60>,
#   <matplotlib.lines.Line2D at 0x1c82addc580>,
#   <matplotlib.lines.Line2D at 0x1c82ade7d60>,
#   <matplotlib.lines.Line2D at 0x1c82adfd580>,
#   <matplotlib.lines.Line2D at 0x1c829dc9d60>,
#   <matplotlib.lines.Line2D at 0x1c829dde580>,
#   <matplotlib.lines.Line2D at 0x1c829dead60>,
#   <matplotlib.lines.Line2D at 0x1c829e00580>,
#   <matplotlib.lines.Line2D at 0x1c829e0ed60>,
#   <matplotlib.lines.Line2D at 0x1c829e26580>,
#   <matplotlib.lines.Line2D at 0x1c829e32d60>,
#   <matplotlib.lines.Line2D at 0x1c829e4a580>,
#   <matplotlib.lines.Line2D at 0x1c829e56d60>,
#   <matplotlib.lines.Line2D at 0x1c829e6c580>,
#   <matplotlib.lines.Line2D at 0x1c829e77d60>,
#   <matplotlib.lines.Line2D at 0x1c829e8e580>,
#   <matplotlib.lines.Line2D at 0x1c829e9bd60>,
#   <matplotlib.lines.Line2D at 0x1c829eb1580>,
#   <matplotlib.lines.Line2D at 0x1c829ebcd60>,
#   <matplotlib.lines.Line2D at 0x1c829ed3580>,
#   <matplotlib.lines.Line2D at 0x1c829eded60>,
#   <matplotlib.lines.Line2D at 0x1c829ef7580>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c82ab87850>,
#   <matplotlib.lines.Line2D at 0x1c82ac74310>,
#   <matplotlib.lines.Line2D at 0x1c82a5d5f40>,
#   <matplotlib.lines.Line2D at 0x1c82a5de340>,
#   <matplotlib.lines.Line2D at 0x1c82a5e5df0>,
#   <matplotlib.lines.Line2D at 0x1c82acfd4c0>,
#   <matplotlib.lines.Line2D at 0x1c829da8d30>,
#   <matplotlib.lines.Line2D at 0x1c82ad09970>,
#   <matplotlib.lines.Line2D at 0x1c82adc06a0>,
#   <matplotlib.lines.Line2D at 0x1c82adcbe80>,
#   <matplotlib.lines.Line2D at 0x1c82ade76a0>,
#   <matplotlib.lines.Line2D at 0x1c82adeee80>,
#   <matplotlib.lines.Line2D at 0x1c829dc96a0>,
#   <matplotlib.lines.Line2D at 0x1c829dd4e80>,
#   <matplotlib.lines.Line2D at 0x1c829dea6a0>,
#   <matplotlib.lines.Line2D at 0x1c829df7e80>,
#   <matplotlib.lines.Line2D at 0x1c829e0e6a0>,
#   <matplotlib.lines.Line2D at 0x1c829e1ae80>,
#   <matplotlib.lines.Line2D at 0x1c829e326a0>,
#   <matplotlib.lines.Line2D at 0x1c829e3ee80>,
#   <matplotlib.lines.Line2D at 0x1c829e566a0>,
#   <matplotlib.lines.Line2D at 0x1c829e61e80>,
#   <matplotlib.lines.Line2D at 0x1c829e776a0>,
#   <matplotlib.lines.Line2D at 0x1c829e84e80>,
#   <matplotlib.lines.Line2D at 0x1c829e9b6a0>,
#   <matplotlib.lines.Line2D at 0x1c829ea6e80>,
#   <matplotlib.lines.Line2D at 0x1c829ebc6a0>,
#   <matplotlib.lines.Line2D at 0x1c829ec9e80>,
#   <matplotlib.lines.Line2D at 0x1c829ede6a0>,
#   <matplotlib.lines.Line2D at 0x1c829eebe80>,
#   <matplotlib.lines.Line2D at 0x1c829f016a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c82aba4df0>,
#   <matplotlib.lines.Line2D at 0x1c82ac918b0>,
#   <matplotlib.lines.Line2D at 0x1c82a5f1610>,
#   <matplotlib.lines.Line2D at 0x1c82a5deb20>,
#   <matplotlib.lines.Line2D at 0x1c82a5e55e0>,
#   <matplotlib.lines.Line2D at 0x1c82acfdee0>,
#   <matplotlib.lines.Line2D at 0x1c82ad00520>,
#   <matplotlib.lines.Line2D at 0x1c82ad093a0>,
#   <matplotlib.lines.Line2D at 0x1c82adc0a00>,
#   <matplotlib.lines.Line2D at 0x1c82addc220>,
#   <matplotlib.lines.Line2D at 0x1c82ade7a00>,
#   <matplotlib.lines.Line2D at 0x1c82adfd220>,
#   <matplotlib.lines.Line2D at 0x1c829dc9a00>,
#   <matplotlib.lines.Line2D at 0x1c829dde220>,
#   <matplotlib.lines.Line2D at 0x1c829deaa00>,
#   <matplotlib.lines.Line2D at 0x1c829e00220>,
#   <matplotlib.lines.Line2D at 0x1c829e0ea00>,
#   <matplotlib.lines.Line2D at 0x1c829e26220>,
#   <matplotlib.lines.Line2D at 0x1c829e32a00>,
#   <matplotlib.lines.Line2D at 0x1c829e4a220>,
#   <matplotlib.lines.Line2D at 0x1c829e56a00>,
#   <matplotlib.lines.Line2D at 0x1c829e6c220>,
#   <matplotlib.lines.Line2D at 0x1c829e77a00>,
#   <matplotlib.lines.Line2D at 0x1c829e8e220>,
#   <matplotlib.lines.Line2D at 0x1c829e9ba00>,
#   <matplotlib.lines.Line2D at 0x1c829eb1220>,
#   <matplotlib.lines.Line2D at 0x1c829ebca00>,
#   <matplotlib.lines.Line2D at 0x1c829ed3220>,
#   <matplotlib.lines.Line2D at 0x1c829edea00>,
#   <matplotlib.lines.Line2D at 0x1c829ef7220>,
#   <matplotlib.lines.Line2D at 0x1c829f01a00>],
#  'means': []}

# %% [markdown]
# All features except time have outliers

# %%
countplot = sns.countplot(x=df['Class'], data=df, palette='Set1')
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Count Plot for Class')
plt.show()

# %% [markdown]
# Dataset is highly imbalanced

# %%
# Visualization of the features of the dataset using Distribution Plots
for cols in df.columns:
    distributionplot = sns.distplot(a=df[cols], bins=10, hist=True, kde=True)
    plt.xlabel(cols)
    plt.ylabel('Frequency')
    plt.title('Distribution plot for ' + cols)
    plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# All the features are skewed, hence require scaling

# %% [markdown]
# ###### Step 4: Data Preprocessing

# %% [markdown]
# Data Preprocessing on Train Data

# %%
# Input DataFrame
X=df.iloc[:,0:-1]
X.head()
# Out:
#     Time        V1        V2        V3        V4        V5        V6  \
# 0    0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 10  10.0  1.449044 -1.176339  0.913860 -1.375667 -1.971383 -0.629152
# 20  16.0  0.694885 -1.361819  1.029221  0.834159 -1.191209  1.309109
# 30  24.0  1.237429  0.061043  0.380526  0.761564 -0.359771 -0.494084
# 40  32.0  1.249055 -0.624727 -0.710589 -0.991600  1.429973  3.692977
#
#           V7        V8        V9       V10       V11       V12       V13  \
# 0   0.239599  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390
# 10 -1.423236  0.048456 -1.720408  1.626659  1.199644 -0.671440 -0.513947
# 20 -0.878586  0.445290 -0.446196  0.568521  1.019151  1.298329  0.420480
# 30  0.006494 -0.133862  0.438810 -0.207358 -0.929182  0.527106  0.348676
# 40 -1.090209  0.967291  0.850149 -0.307081 -0.456245  0.229981 -0.016913
#
#          V14       V15       V16       V17       V18       V19       V20  \
# 0  -0.311169  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412
# 10 -0.095045  0.230930  0.031967  0.253415  0.854344 -0.221365 -0.387226
# 20 -0.372651 -0.807980 -2.044557  0.515663  0.625847 -1.300408 -0.138334
# 30 -0.152535 -0.218386 -0.191552 -0.116581 -0.633791  0.348416 -0.066351
# 40 -0.220846  0.362418  0.315222 -0.512265  0.118995  0.574720  0.097853
#
#          V21       V22       V23       V24       V25       V26       V27  \
# 0  -0.018307  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558
# 10 -0.009302  0.313894  0.027740  0.500512  0.251367 -0.129478  0.042850
# 20 -0.295583 -0.571955 -0.050881 -0.304215  0.072001 -0.422234  0.086553
# 30 -0.245682 -0.530900 -0.044265  0.079168  0.509136  0.288858 -0.022705
# 40 -0.006293  0.009200 -0.129463  1.112970  0.500382  1.196549 -0.048220
#
#          V28  Amount
# 0  -0.021053  149.62
# 10  0.016253    7.80
# 20  0.063499  231.71
# 30  0.011836   17.28
# 40  0.005094   29.89

# %%
# Target DataFrame
Y=df.iloc[:,-1]
Y.head()
# Out:
# 0     0.0
# 10    0.0
# 20    0.0
# 30    0.0
# 40    0.0
# Name: Class, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
for cols in X_train.columns:
    bp = sns.boxplot(X_train[cols])
    plt.xlabel(cols)
    plt.title('Boxplot for ' + cols)
    plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
X_train[X_train.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Time, V1, V2, V3, V4, V5, V6, V7, V8, V9, V10, V11, V12, V13, V14, V15, V16, V17, V18, V19, V20, V21, V22, V23, V24, V25, V26, V27, V28, Amount]
# Index: []

# %%
X_train.dropna(inplace=True)

# %%
Y_train.dropna(inplace=True)

# %%
# Handling the outliers using quantile-based Capping and Flooring techniqueupper_limit = X_train['bmi'].quantile(0.99)
for col in X_train.columns:
    upper_limit = X_train[col].quantile(0.99)
    lower_limit = X_train[col].quantile(0.01)
    X_train[col] = np.where(X_train[col] >= upper_limit, upper_limit,
            np.where(X_train[col] <= lower_limit, lower_limit, X_train[col]))

# %% [markdown]
# Data Preprocessing on Testing Data

# %%
for cols in X_test.columns:
    bp = sns.boxplot(X_test[cols])
    plt.xlabel(cols)
    plt.title('Boxplot for ' + cols)
    plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Handling the outliers using quantile-based Capping and Flooring techniqueupper_limit = X_train['bmi'].quantile(0.99)
for col in X_test.columns:
    upper_limit = X_test[col].quantile(0.99)
    lower_limit = X_test[col].quantile(0.01)
    X_test[col] = np.where(X_test[col] >= upper_limit, upper_limit,
            np.where(X_test[col] <= lower_limit, lower_limit, X_test[col]))

# %% [markdown]
# ##### Feature Scaling (standardizing the features)

# %%
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()
scaler.fit_transform(X_train)
scaler.transform(X_test)
# Out:
# array([[ 0.69497652, -0.69732768,  1.91470661, ...,  2.19858676,
#          1.7380146 , -0.4915894 ],
#        [-0.15700601, -0.40601128,  0.96273733, ...,  0.21256206,
#         -0.82047587, -0.40275397],
#        [ 0.3243142 , -0.477822  ,  0.53594469, ...,  0.07513381,
#         -0.29857023, -0.4744059 ],
#        ...,
#        [ 0.49979986,  0.00372914, -0.27225712, ...,  1.08215055,
#          0.56907115, -0.37026743],
#        [-0.94783549, -0.22069784,  1.29609989, ...,  0.73269021,
#         -1.04065899,  0.08357139],
#        [-0.79048081,  0.68487324, -0.3702442 , ..., -0.57475496,
#          0.018289  ,  0.59589894]])

# %% [markdown]
# ##### Handling the imbalanced dataset
# Applying the SMOTE technique to handle the unbalanced dataset

# %%
from collections import Counter
print('Original dataset target feature category counter {}'.format(Counter(Y_train)))
# Out:
# Original dataset target feature category counter Counter({0.0: 13920, 1.0: 33})

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()
X_train, Y_train = sm.fit_resample(X_train,Y_train)
print('Resampled dataset target feature category counter {}'.format(Counter(Y_train)))
# Out:
# Resampled dataset target feature category counter Counter({0.0: 13920, 1.0: 13920})

# %% [markdown]
# ###### Step 5: Model Building

# %%
import xgboost as xgb
model_xgboost = xgb.XGBClassifier(learning_rate=0.1, n_estimators=100)

model_xgboost.fit(X_train,Y_train)

Y_pred_train_xgboost = model_xgboost.predict(X_train)
Y_pred_test_xgboost = model_xgboost.predict(X_test)
Y_proba_test_xgboost = model_xgboost.predict_proba(X_test)

# %% [markdown]
# ###### Step 6: Model Evaluation

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, recall_score, f1_score, precision_score, plot_confusion_matrix, roc_auc_score
print('\nConfusion Matrix:\n')
plot_confusion_matrix(model_xgboost, X_test, Y_test)
# Out:
# Confusion Matrix:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
print('\nClassification Report:\n')
print(classification_report(Y_test, Y_pred_test_xgboost))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      3484
#          1.0       0.50      1.00      0.67         5
#
#     accuracy                           1.00      3489
#    macro avg       0.75      1.00      0.83      3489
# weighted avg       1.00      1.00      1.00      3489

# %%
print('Train accuracy: ' + str(accuracy_score(Y_train, Y_pred_train_xgboost)))
print('Test accuracy: ' + str(accuracy_score(Y_test, Y_pred_test_xgboost)))
print('Recall Score: ' + str(recall_score(Y_test, Y_pred_test_xgboost)))
print('ROC AUC Score: ' + str(roc_auc_score(Y_test, Y_proba_test_xgboost[:,1])))
# Out:
# Train accuracy: 0.9999640804597701
# Test accuracy: 0.998566924620235
# Recall Score: 1.0
# ROC AUC Score: 1.0
